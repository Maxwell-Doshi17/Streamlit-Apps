# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
dict1 = {
    "Country" : ["Canada", "Mexico", "France", "Spain", "Germany", "Algeria", "India", "Latvia"],
    "Capital" : ["Ottawa", "Mexico City", "Paris", "Madrid", "Berlin", "Algiers", "New Dehli", "Riga"]
    }
df = pd.read_csv("geo-capitals_EN.csv")
df
# Out:
#     ISO Alpha-2 ISO Alpha-3      Country           Capital  Latitude  \
# 0            AF         AFG  Afghanistan             Kabul     34.52
# 1            AL         ALB      Albania            Tirana     41.32
# 2            DZ         DZA      Algeria           Algiers     36.75
# 3            AD         AND      Andorra  Andorra la Vella     42.50
# 4            AO         AGO       Angola            Luanda     -8.83
# ..          ...         ...          ...               ...       ...
# 190          VE         VEN    Venezuela           Caracas     10.48
# 191          VN         VNM      Vietnam             Hanoi     21.03
# 192          YE         YEM        Yemen            Sana'a     15.37
# 193          ZM         ZMB       Zambia            Lusaka    -15.42
# 194          ZW         ZWE     Zimbabwe            Harare    -17.82
#
#      Longitude
# 0        69.18
# 1        19.82
# 2         3.05
# 3         1.52
# 4        13.22
# ..         ...
# 190     -66.87
# 191     105.85
# 192      44.19
# 193      28.28
# 194      31.03
#
# [195 rows x 6 columns]

# %%
def round():
    current = df.sample(4, replace=False)
    selection = current.sample(1)
    print(selection["Country"])
    print(current["Capital"])
    guess = input()
    if guess == selection["Capital"].values[0]:
        return "Correct!"
    else:
        return "False!"

round()
# Out:
# 4    Angola
# Name: Country, dtype: object
# 122          Wellington
# 185    Washington, D.C.
# 4                Luanda
# 100        Antananarivo
# Name: Capital, dtype: object
# 'Correct!'
